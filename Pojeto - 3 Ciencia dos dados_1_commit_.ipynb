# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import random

# %%
ndata = pd.read_csv('USvideos.csv').loc[:, ["trending_date","title","channel_title","category_id","publish_time","tags","views","likes","dislikes","comment_count","thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed","description"]]

lnks = ndata.loc[:, ["title","thumbnail_link", "views"]].drop_duplicates(subset = "thumbnail_link", keep = "last").reset_index(drop = True)

# %%
# import urllib.request as req

# x = []
# z = []
# c = 0

# for i in lnks["thumbnail_link"]:
    
#     if c <= 5000:
        
#         try:
#             req.urlretrieve(i, "{}.jpg".format(c))
#             x.append(lnks["views"][lnks.thumbnail_link[lnks.thumbnail_link == i].index.tolist()[0]])
#             z.append(lnks["title"][lnks.thumbnail_link[lnks.thumbnail_link == i].index.tolist()[0]])
#             c += 1
            
#         except:
#             pass
    
#     else:
#         break
    
# print(c)
# Out:
# 5001

# %%
# # Remove emojis    ------------[
        
# import re
        
# emoji_pattern = re.compile(
#     u"(\ud83d[\ude00-\ude4f])|"  # emoticons
#     u"(\ud83c[\udf00-\uffff])|"  # symbols & pictographs (1 of 2)
#     u"(\ud83d[\u0000-\uddff])|"  # symbols & pictographs (2 of 2)
#     u"(\ud83d[\ude80-\udeff])|"  # transport & map symbols
#     u"(\ud83c[\udde0-\uddff])"  # flags (iOS)
#     "+", flags=re.UNICODE)
        
# #     ]------------------------

# %%
# Importando Vectorizer    ------------------------[

from sklearn.feature_extraction.text import CountVectorizer


# ]--------------------------

# %%
vectorizer = CountVectorizer()
vect = vectorizer.fit_transform(z)
vect = vect.toarray()

np.savetxt('z.txt', vect, delimiter=' ')

# %%
# with open('z.txt', 'w') as f:
#     for item in vect:
        
# #       emoji_pattern.sub(r'', item)
#         f.write(item + "\n")

# with open('x.txt', 'w') as f:
#     for item in x:
#         f.write(str(item) + "\n")

# %%
# faixa 1 = 0, 100652.364
# faixa 2 = 100652.364, 504283.8
# faixa 3 = 504283.8, 1008510.6
# faixa 4 = 1008510.6, 5127377.4
# faixa 5 = 5127377.4, 50169650.2
# faixa 6 = 50169650.2, 225211923.0

views_y = []

with open('x.txt', 'r') as f:
    for item in f:
        if int(item[:-1]) < 100000:
            views_y.append(1)
        
        if int(item[:-1]) > 100000 and int(item[:-1]) < 500000:
            views_y.append(2)
        
        if int(item[:-1]) > 500000 and int(item[:-1]) < 1000000:
            views_y.append(3)
        
        if int(item[:-1]) > 1000000 and int(item[:-1]) < 5000000:
            views_y.append(4)
        
        if int(item[:-1]) > 5000000 and int(item[:-1]) < 50000000:
            views_y.append(5)
        
        if int(item[:-1]) > 50000000 and int(item[:-1]) < 225211923.0:
            views_y.append(6)

# %%
import numpy as np
import cv2

imagens_x = []

for i in range(5001):
    im = cv2.imread('{}.jpg'.format(i))
    img_crop = cv2.pyrDown(im)
    img_crop = cv2.pyrDown(img_crop)
    img_crop = cv2.cvtColor(img_crop, cv2.COLOR_BGR2RGB)
    imagens_x.append(img_crop.flatten())

# %%
shuff = list(zip(imagens_x, views_y))

random.shuffle(shuff)

imagens_x, views_y = zip(*shuff)

# %%
index = round(len(imagens_x)*0.95)
imagens_x_train, imagens_x_test = imagens_x[:index], imagens_x[index:]
len(imagens_x_train)

# %%
views_y
index_ = round(len(views_y)*0.95)
views_y_train, views_y_test = views_y[:index_], views_y[index_:]
len(views_y_train)

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier(loss = "hinge", penalty = "l2", max_iter = 100)
clf.fit(imagens_x_train, views_y_train)
y_pred = clf.predict(imagens_x_test)
print('Acurácia: {}'.format(accuracy_score(views_y_test, y_pred)))

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 100, max_depth = 2,random_state = 0)
clf.fit(imagens_x_train, views_y_train)
y_pred = clf.predict(imagens_x_test)
print('Acurácia: {}'.format(accuracy_score(views_y_test, y_pred)))

# %%
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier

rbf_feature = RBFSampler(gamma = 1, random_state = 1)
X_features = rbf_feature.fit_transform(imagens_x_train)
clf = SGDClassifier(max_iter = 100)
clf.fit(imagens_x_train, views_y_train) 
y_pred = clf.predict(imagens_x_test)
print('Acurácia: {}'.format(accuracy_score(views_y_test, y_pred)))

# %%
from sklearn import svm

clf = svm.SVC(gamma = 'scale')
clf.fit(imagens_x_train, views_y_train) 
y_pred = clf.predict(imagens_x_test)
print('Acurácia: {}'.format(accuracy_score(views_y_test, y_pred)))

# %% [markdown]
# ---

# %%
y_pred

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# O Objetivo do projeto é indentificar em qual faixa de views (0 - 100 mil, ...) um vídeo vai estar, dada somente sua tumbnail como entrada. Para isso, foi baixado um dataset contendo diversas variáveis como "likes", "dislikes", ..., etc. Cada coluna diz respeito a algum feature que o youtube utiliza como caracteristicas do video, como pode ser visto abaixo:

# %%
ndata
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# 5          17.14.11                              2 Weeks with iPhone X
# 6          17.14.11          Roy Moore & Jeff Sessions Cold Open - SNL
# 7          17.14.11                5 Ice Cream Gadgets put to the Test
# 8          17.14.11  The Greatest Showman | Official Trailer 2 [HD]...
# 9          17.14.11  Why the rise of the robots won’t mean the end ...
# 10         17.14.11  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# 11         17.14.11  (SPOILERS) 'Shiva Saves the Day' Talked About ...
# 12         17.14.11         Marshmello - Blocks (Official Music Video)
# 13         17.14.11             Which Countries Are About To Collapse?
# 14         17.14.11                           SHOPPING FOR NEW FISH!!!
# 15         17.14.11                                   The New SpotMini
# 16         17.14.11   One Change That Would Make Pacific Rim a Classic
# 17         17.14.11  How does your body know you're full? - Hilary ...
# 18         17.14.11                         HomeMade Electric Airplane
# 19         17.14.11           Founding An Inbreeding-Free Space Colony
# 20         17.14.11                   How Can You Control Your Dreams?
# 21         17.14.11  The Making of Hela's Headdress from Thor: Ragn...
# 40930  2018-05-22T04:08:24.000Z
# 40931  2018-05-21T21:00:33.000Z
# 40932  2018-05-22T02:34:39.000Z
# 40933  2018-05-20T21:00:00.000Z
# 40934  2018-05-20T04:58:51.000Z
# 40935  2018-05-20T07:53:59.000Z
# 40936  2018-05-20T18:00:02.000Z
# 40937  2018-05-19T14:52:43.000Z
# 40938  2018-05-18T14:00:04.000Z
# 40939  2018-05-18T14:00:04.000Z
# 40940  2018-05-18T17:13:08.000Z
# 40941  2018-05-18T04:04:58.000Z
# 40942  2018-05-18T07:00:08.000Z
# 40943  2018-05-18T16:39:29.000Z
# 40944  2018-05-18T13:00:04.000Z
# 40945  2018-05-18T01:00:06.000Z
# 40946  2018-05-18T17:34:22.000Z
# 40947  2018-05-17T17:00:04.000Z
# 40948  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# 5      ijustine|"week with iPhone X"|"iphone x"|"appl...    119180    9763
# 6      SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   2103417   15993
# 7      5 Ice Cream Gadgets|"Ice Cream"|"Cream Sandwic...    817732   23663
# 8      Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...    826059    3543
# 9      vox.com|"vox"|"explain"|"shift change"|"future...    256426   12654
# 10     NFL|"Football"|"offense"|"defense"|"afc"|"nfc"...     81377     655
# 11     The Walking Dead|"shiva"|"tiger"|"king ezekiel...    104578    1576
# 12     marshmello|"blocks"|"marshmello blocks"|"block...    687582  114188
# 13     nowthis|"nowthis world"|"world news"|"nowthis ...    544770    7848
# 14     shopping for new fish|"new fish"|"aquarium fis...    207532    7473
# 15     Robots|"Boston Dynamics"|"SpotMini"|"Legged Lo...     75752    9419
# 16     pacific rim|"pacific rim 2"|"pacific rim seque...    295639    8011
# 17     TED|"TED-Ed"|"TED Education"|"TED Ed"|"Hilary ...     78044    5398
# 18     ultralight|"airplane"|"homemade"|"DIY"|"hoverb...     97007   11963
# 19     SciShow|"science"|"Hank"|"Green"|"education"|"...    223871    8421
# 20     life noggin|"life noggin youtube"|"youtube lif...    115791    9586
# 21     tested|"testedcom"|"designercon 2017"|"preview...    224019    3585
# 22     tom scott|"tomscott"|"built for science"|"nati...    144418   11758
# 23     refinery29|"refinery 29"|"r29"|"r29 video"|"vi...    145921    1707
# 24     using other peoples showers|"gus"|"gus shower"...     33980    4884
# 25     spaghetti burrito|"diy burrito"|"spaghetti"|"b...    223077    8676
# 26             numberphile|"prime numbers"|"proth prime"     80705    4687
# 27     Smart mug|"Heated thermos"|"tech"|"gift idea"|...    120727    9033
# 28                                     auth-jvardon-auth     27943     156
# 29     freaks and geeks|"jason segel"|"judd apatow"|"...     50867     715
# ...                                                  ...       ...     ...
# 40919  fortnite|"fortnite pc"|"fortnite battle royale...    324219    7840
# 40920  Christina Aguilera feat. Demi Lovato|"Fall In ...  16777231  518106
# 40921  James Bay|"Taylor Swift"|"Delicate"|"BBC"|"Rad...    832097   28479
# 40922  The Tonight Show|"Jimmy Fallon"|"Mindy Kaling"...    588133    6583
# 40923  camels|"cactus"|"pets"|"livestock"|"animals"|"...   5985284   33243
# 40924  Matt Stonie|"Megatoad"|"Competitive Eating"|"F...   2025376   50919
# 40925  Welcome to the party|"Diplo"|"Lil Pump"|"Frenc...  40087764  835657
# 40926  tyler the creator|"435"|"nice toenails"|"golf ...   2252933  129865
# 40927  dinosaurs|"dinos"|"paleo"|"paleontology"|"scis...   1925345   46673
# 40928  nat geo wild|"national geographic"|"wild"|"wil...   1165339   20248
# 40929  Mustard|"Nick"|"Jonas"|"Anywhere"|"10"|"Summer...   2653229   48889
# 40930  ABC|"americanidol"|"idol"|"american idol"|"rya...   2003345   19895
# 40931  terrible magicians|"rudy"|"mancuso"|"juanpa"|"...   3825440  196635
# 40932  the voice season 14|"the voice finale performa...   1437051   19930
# 40933  SciShow|"science"|"Hank"|"Green"|"education"|"...    979732   29038
# 40934  SNL|"Saturday Night Live"|"SNL Season 43"|"SNL...   8607264   66559
# 40935  Nicki Minaj new music|"Nicki Minaj Queen"|"Nic...   4945185  189265
# 40936  miniminter|"mm7games"|"simon"|"random"|"lie de...   3229540  109945
# 40937   LucastheSpider|"Animation"|"3D Animation"|"Cute"   8300584  266267
# 40938  daddy yankee reggaeton|"daddy yankee youtube"|...  41803845  628861
# 40939  Garden (Say It Like Dat)|"R&B"|"SZA"|"Top Dawg...   6004782  210802
# 40940  Graham Norton|"Graham Norton Show Official"|"E...   5564576   46351
# 40941  wedding video|"heartfelt wedding video"|"emoti...   5534278   45128
# 40942  fifth hamony|"harmonizers"|"lauren"|"ally"|"no...  23502572  676467
# 40943  BuzzFeed|"BuzzFeedVideo"|"Puppy Interview"|"pu...   8259128  645888
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# 5           511           1434
# 6          2445           1970
# 7           778           3432
# 8           119            340
# 9          1363           2368
# 10           25            177
# 11          303           1279
# 12         1333           8371
# 13         1171           3981
# 14          246           2120
# 15           52           1230
# 16          638           1256
# 17           53            385
# 18           36           2211
# 19          191           1214
# 20           75           2800
# 21          138            208
# 22           89           1014
# 23          578            673
# 24           52            234
# 25          193           1392
# 26           41            437
# 27          224           1346
# 28           36             83
# 29          238            246
# ...         ...            ...
# 40919      1333           1257
# 40920     14427          26162
# 40921       543            936
# 40922       381            486
# 40923      4899          16703
# 40924      2127           8253
# 40925     25283          38305
# 40926      1550           6673
# 40927      1765           4973
# 40928       668           2261
# 40929       890           1181
# 40930      2831           3481
# 40931      4514          11203
# 40932      1794           1671
# 40933      1121           2584
# 40934     14179           8382
# 40935      9406          18683
# 40936      3062           6774
# 40937      4237          14617
# 40938     42833          39363
# 40939      4166          15169
# 40940      2295           2861
# 40941      1591            806
# 40942     15993          52432
# 40943      4052          62610
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 40930  https://i.ytimg.com/vi/wI89nVn6LHk/default.jpg              False
# 40931  https://i.ytimg.com/vi/oLDbO545aKQ/default.jpg              False
# 40932  https://i.ytimg.com/vi/tiF9SzzzX_o/default.jpg              False
# 40933  https://i.ytimg.com/vi/Gs26bZTRkdU/default.jpg              False
# 40934  https://i.ytimg.com/vi/Qcj15vHJTtk/default.jpg              False
# 40935  https://i.ytimg.com/vi/2in8XqiElwc/default.jpg              False
# 40936  https://i.ytimg.com/vi/Xr2rgT9uEnA/default.jpg              False
# 40937  https://i.ytimg.com/vi/v7H_Or9Nr5I/default.jpg              False
# 40938  https://i.ytimg.com/vi/n_W54baizX8/default.jpg              False
# 40939  https://i.ytimg.com/vi/pcJo0tIWybY/default.jpg              False
# 40940  https://i.ytimg.com/vi/_QWZvU7VCn8/default.jpg              False
# 40941  https://i.ytimg.com/vi/7UoP9ABJXGE/default.jpg              False
# 40942  https://i.ytimg.com/vi/ju_inUnrLc4/default.jpg              False
# 40943  https://i.ytimg.com/vi/1PhPYr_9zRY/default.jpg              False
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# 5                 False                   False
# 6                 False                   False
# 7                 False                   False
# 8                 False                   False
# 9                 False                   False
# 10                False                   False
# 11                False                   False
# 12                False                   False
# 13                False                   False
# 14                False                   False
# 15                False                   False
# 16                False                   False
# 17                False                   False
# 18                False                   False
# 19                False                   False
# 20                False                   False
# 21                False                   False
# 22                False                   False
# 23                False                   False
# 24                False                   False
# 25                False                   False
# 26                False                   False
# 27                False                   False
# 28                False                   False
# 29                False                   False
# ...                 ...                     ...
# 40919             False                   False
# 40920             False                   False
# 40921             False                   False
# 40922             False                   False
# 40923             False                   False
# 40924             False                   False
# 40925             False                   False
# 40926             False                   False
# 40927             False                   False
# 40928             False                   False
# 40929             False                   False
# 40930             False                   False
# 40931             False                   False
# 40932             False                   False
# 40933             False                   False
# 40934             False                   False
# 40935             False                   False
# 40936             False                   False
# 40937             False                   False
# 40938             False                   False
# 40939             False                   False
# 40940             False                   False
# 40941             False                   False
# 40942             False                   False
# 40943             False                   False
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# 5      Using the iPhone for the past two weeks -- her...
# 6      Embattled Alabama Senate candidate Roy Moore (...
# 7      Ice Cream Pint Combination Lock - http://amzn....
# 8      Inspired by the imagination of P.T. Barnum, Th...
# 9      For now, at least, we have better things to wo...
# 10     New England Patriots returner Dion Lewis blast...
# 11     Shiva arrives just in time as King Ezekiel att...
# 12     WATCH SILENCE MUSIC VIDEO ▶ https://youtu.be/T...
# 13     The world at large is improving, but some coun...
# 14     Today we go shopping for new fish for some of ...
# 15                For more information . . . stay tuned.
# 16     Pacific Rim was so good, we can’t believe they...
# 17     Check out our Patreon page: https://www.patreo...
# 18     aaaannnd now to fly out of ground effect! The ...
# 19     Thanks to 23AndMe for supporting SciShow. Thes...
# 20     What if there was a way to control your dreams...
# 21     At this year's DesignerCon, we meet up with Ir...
# 22     I'm visiting the University of Iowa's National...
# 23     On this episode of Sweet Digs, we tour Social ...
# 24     Why is it so hard to figure out other people's...
# 25     Visit http://www.Bongiovibrand.com\nand get 20...
# 26     James Grime is back and talking prime numbers....
# 27     YouTubes new channel!: https://www.youtube.com...
# 28     LeBron James gave another all-time press confe...
# 29     The opening of Freaks and Geeks Episode 6, I'm...
# ...                                                  ...
# 40919  Thanks to Skillshare for sponsoring this video...
# 40920  Pre-order Christina Aguilera’s new album ‘Libe...
# 40921  James Bay covers Taylor Swift's Delicate in th...
# 40922  Mindy Kaling chats with Jimmy about his though...
# 40923  Dromedary camels tear through prickly pear cac...
# 40924  Download Fortnite!! https://pixly.go2cloud.org...
# 40925  Official Video | Diplo, French Montana & Lil P...
# 40926  a random song laying around from the flower bo...
# 40927  Check out our NEW POSTER: https://store.dftba....
# 40928  Watch this beetle go from larvae to giant. The...
# 40929  Anywhere Out Now! http://smarturl.it/AnywhereM...
# 40930  Maddie Poppe the crowd the American Idol 2018 ...
# 40931  WATCH MORE ▶ https://youtu.be/Q9_WGkd_svIWATCH...
# 40932  Brynn Cartelli sings Adele's Skyfall during th...
# 40933  You might think you know how to survive if you...
# 40934  Footage from Prince Harry's (Mikey Day) weddin...
# 40935  Chun-Li (Live on SNL / 2018)Song Available Her...
# 40936  Talia: https://www.youtube.com/user/nataliahad...
# 40937  Lucas is a tiny spider to some...giant arachni...
# 40938  Daddy Yankee - Hielo (Video Oficial)Spotify: h...
# 40939  SZA's CTRL available on:Apple Music - http://s...
# 40940  Check out all that Emilia Clarke merch... Subs...
# 40941  Stream + Download:https://wmna.sh/speechlessht...
# 40942  Fifth Harmony available at iTunes http://smart...
# 40943  BTS with the PPS, the puppies. These adorable ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 15 columns]

# %% [markdown]
# Como o nosso projeto consta somente com a imagem, cortamos o dataset em um com apenas o link das tumbnails e o número de views do vídeo. É importante dizer que os dados foram atualizados todos os dias durante o tempo, o que significa que existem videos iguais em diferentes dias, e por isso utilizamos do ferramental pandas para tirar todas as tumbnails iguais. Por conta disso, em alguns casos o número de views é diferente para o mesmo link (vídeo), optamos por considerar a ultima vez q o dataset foi atualizado, ou seja, o maior número de views de um vídeo igual.

# %%
lnks
# Out:
#                                                   title  \
# 0     Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# 1        TL;DW - Every DCEU Movie Before Justice League
# 2     Iraq-Iran earthquake: Deadly tremor hits borde...
# 3     Jason Momoa Wows Hugh Grant With Some Dothraki...
# 4     Mayo Clinic's first face transplant patient me...
# 5         Jason Momoa & Lisa Bonet: Love at First Sight
# 6     Mark Wahlberg's Kids Use Him for His Celeb Con...
# 7     Camila Cabello - Havana (Vertical Video) ft. Y...
# 6337  https://i.ytimg.com/vi/Qcj15vHJTtk/default.jpg   8607264
# 6338  https://i.ytimg.com/vi/2in8XqiElwc/default.jpg   4945185
# 6339  https://i.ytimg.com/vi/Xr2rgT9uEnA/default.jpg   3229540
# 6340  https://i.ytimg.com/vi/v7H_Or9Nr5I/default.jpg   8300584
# 6341  https://i.ytimg.com/vi/n_W54baizX8/default.jpg  41803845
# 6342  https://i.ytimg.com/vi/pcJo0tIWybY/default.jpg   6004782
# 6343  https://i.ytimg.com/vi/_QWZvU7VCn8/default.jpg   5564576
# 6344  https://i.ytimg.com/vi/7UoP9ABJXGE/default.jpg   5534278
# 6345  https://i.ytimg.com/vi/ju_inUnrLc4/default.jpg  23502572
# 6346  https://i.ytimg.com/vi/1PhPYr_9zRY/default.jpg   8259128
# 6347  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg   1685609
# 6348  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg   1064798
# 6349  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg   1066451
# 6350  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg   5660813
# 6351  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg  10306119
#
# [6352 rows x 3 columns]

# %% [markdown]
# Com o banco de dados pronto para ser utilizado, o próximo passo seria baixar as fotos para o computador, para otimizar o tempo na hora de trabalhar no modelo. Como muitas tumbnails não existem (vídeo removido, não existe mais foto), foi utilizado o try, e logo depois adicionado o número de views a uma lista chamada "x" (não tem relação com o modelo, o nome "x" é apenas representativo).
#
#     import urllib.request as req
#
#     x = []
#     c = 0
#
#     for i in lnks["thumbnail_link"]:
#
#         if c <= 5000:
#
#             try:
#                 req.urlretrieve(i, "{}.jpg".format(c))
#                 x.append(lnks["views"][lnks.thumbnail_link[lnks.thumbnail_link == i].index.tolist()[0]])
#                 c += 1
#
#             except:
#                 pass
#
#         else:
#             break
#
#     print(c)

# %% [markdown]
# Além disso, como nosso modelo adota o uso de imagens para análise do numero de views, não é possível plotar histogramas ou boxplots, o que nos leva a descartar tal tipo de análise.

# %% [markdown]
# Foi salvo os views da lista "x" em um arquivo para nao ter de rodar novamente o código acima, o que acabaria baixando novamente as fotos.
#
#     with open('x.txt', 'w') as f:
#         for item in x:
#             f.write(str(item) + "\n")
#
# Com o y pronto (número de views) e dividido em faixas, o próximo passo seria achar algum meio de transformar as imagens baixadas em um array que representaria o x do modelo.

# %% [markdown]
# Para isso foi utilizado o cv2 para ler e converter as imagens em array, e prontas para serem utilizadas no modelo.
#
#     import numpy as np
#     import cv2
#
#     imagens_x = []
#
#     for i in range(5001):
#         im = cv2.imread('{}.jpg'.format(i))
#         img_crop = cv2.pyrDown(im)
#         img_crop = cv2.pyrDown(img_crop)
#         img_crop = cv2.cvtColor(img_crop, cv2.COLOR_BGR2RGB)
#         imagens_x.append(img_crop.flatten())

# %% [markdown]
# Antes de testar os modelos, algumas alterações foram feitas nas listas x e y, como por exemplo o shuffle. Dividimos 95% das duas listas para treino, e o resto para classificação.
# Ao entrar no site do sikit em "Flow Chart", alguns modelos foram testados seguindo a sugestão do mesmo.
# Como o máximo de acurácia foi 33%, escolhemos entender melhor o que as imagens nos diziam, portanto, o proximo passo para melhorar a acurácia é criar meios de análise da imagem, para ajudar o classificador a melhorar os acertos.
